# %% [markdown]
# # Домашнее задание: декораторы

# %% [markdown]
# ## Импорт библиотек, установка констант

# %%
import requests
import time
import re

from random import randint

# %%
BOOK_PATH = 'https://www.gutenberg.org/files/2638/2638-0.txt'

# %% [markdown]
# ## Задание 1

# %%
def benchmark(func):
    """
    Декоратор, выводящий время, которое заняло выполнение декорируемой функции
    """
    def wrapper(*args, **kwargs):
        start = time.perf_counter()
        result = func(*args, **kwargs)
        end = time.perf_counter()
        print(f'Время выполнения функции {func.__name__}: {end - start}\n')
        return result
    return wrapper

# %% [markdown]
# ## Задание 2

# %%
def logging(func):
    """
    Декоратор, который выводит параметры с которыми была вызвана функция
    """
    def wrapper(*args, **kwargs):
        arg_str = ', '.join(repr(arg) for arg in args)
        result = func(*args, **kwargs)
        print(f'Функция вызвана с параметрами:\n({arg_str}), {kwargs}\n')
        return result
    return wrapper

# %% [markdown]
# ## Задание 3

# %%
def counter(func):
    """
    Декоратор, считающий и выводящий количество вызовов декорируемой функции
    """
    def wrapper(*args, **kwargs):
        wrapper.num_calls += 1
        result = func(*args, **kwargs)
        print(f'Функция была вызвана: {wrapper.num_calls} раз\n')
        return result
    wrapper.num_calls = 0
    return wrapper

# %% [markdown]
# ## Задание 4

# %%
def memo(func):
  """
  Декоратор, запоминающий результаты исполнения функции func, чьи аргументы args должны быть хешируемыми
  """
  cache = {}

  def fmemo(*args):
      if args[0] in cache.keys():
          result = cache[args[0]]
      else:
          result = func(*args)
          cache[args[0]] = result
      return result
  fmemo.cache = cache
  return fmemo

# %% [markdown]
# ## Тестирование

# %%
@counter
@logging
@benchmark
def word_count(word, url=BOOK_PATH):
    """
    Функция для посчета указанного слова на html-странице
    """

    # отправляем запрос в библиотеку Gutenberg и забираем текст
    raw = requests.get(url).text

    # заменяем в тексте все небуквенные символы на пробелы
    processed_book = re.sub('[\W]+' , ' ', raw).lower()

    # считаем
    cnt = len(re.findall(word.lower(), processed_book))

    return f"Cлово {word} встречается {cnt} раз"

print(word_count('whole'))
# Out:
# Время выполнения функции word_count: 0.42296600099962234
#
# Функция вызвана с параметрами:
# ('whole'), {}
#
# Функция была вызвана: 1 раз
#
# Cлово whole встречается 176 раз

# %%
@benchmark
def fib(n):
    """
    Функция вычисления n-го числа Фибоначчи
    """
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
# %%time
fib(20)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Время выполнения функции fib: 5.329299983714009e-05
#
# Время выполнения функции fib: 4.049998096888885e-07
#
# Время выполнения функции fib: 4.2800002120202407e-07
#
# Время выполнения функции fib: 4.3400086724432185e-07
#
# Время выполнения функции fib: 5.301500004861737e-05
#
# Время выполнения функции fib: 0.05110759700073686
#
# Время выполнения функции fib: 0.051259539000056975
#
# Время выполнения функции fib: 0.05142020599942043
#
# Время выполнения функции fib: 0.05166790800012677
#
# Время выполнения функции fib: 6.339996616588905e-07
#
# Время выполнения функции fib: 5.840001904289238e-07
#
# Время выполнения функции fib: 4.579997039400041e-07
#
# Время выполнения функции fib: 5.417800002760487e-05
#
# Время выполнения функции fib: 0.00011904900020454079
#
# Время выполнения функции fib: 4.73000000056345e-07
#
# Время выполнения функции fib: 4.929997885483317e-07
#
# Время выполнения функции fib: 5.1839000661857426e-05
#
# Время выполнения функции fib: 4.3599993659881875e-07
#
# Время выполнения функции fib: 6.609998308704235e-07
#
# Время выполнения функции fib: 5.040001269662753e-07
#
# Время выполнения функции fib: 5.264199990051566e-05
#
# Время выполнения функции fib: 0.00010425700020277873
#
# Время выполнения функции fib: 0.00020724799924209947
#
# Время выполнения функции fib: 0.0003773600001295563
#
# Время выполнения функции fib: 4.860003173234873e-07
#
# Время выполнения функции fib: 4.799994712811895e-07
#
# Время выполнения функции fib: 6.376100009219954e-05
#
# Время выполнения функции fib: 4.3599993659881875e-07
#
# Время выполнения функции fib: 4.719995558843948e-07
#
# Время выполнения функции fib: 4.5399974624160677e-07
#
# Время выполнения функции fib: 5.294899983709911e-05
#
# Время выполнения функции fib: 0.000103674999991199
#
# Время выполнения функции fib: 0.00021809299960295903
#
# Время выполнения функции fib: 5.010006134398282e-07
#
# Время выполнения функции fib: 4.599996827892028e-07
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 5.3609000133292284e-05
#
# Время выполнения функции fib: 0.00010814500001288252
#
# Время выполнения функции fib: 4.4500029616756365e-07
#
# Время выполнения функции fib: 4.3000000005122274e-07
#
# Время выполнения функции fib: 5.2954000238969456e-05
#
# Время выполнения функции fib: 5.020001481170766e-07
#
# Время выполнения функции fib: 5.860001692781225e-07
#
# Время выполнения функции fib: 4.1499970393488184e-07
#
# Время выполнения функции fib: 4.9870000111695845e-05
#
# Время выполнения функции fib: 0.00010122399999090703
#
# Время выполнения функции fib: 0.00020461100029933732
#
# Время выполнения функции fib: 0.0003727980001713149
#
# Время выполнения функции fib: 0.0006467969997174805
#
# Время выполнения функции fib: 0.001070827999683388
#
# Время выполнения функции fib: 0.052786608999667806
#
# Время выполнения функции fib: 0.07379987000058463
#
# Время выполнения функции fib: 0.09899038700041274
#
# Время выполнения функции fib: 0.10105440400002408
#
# Время выполнения функции fib: 4.799994712811895e-07
#
# Время выполнения функции fib: 4.3700038077076897e-07
#
# Время выполнения функции fib: 5.177300045033917e-05
#
# Время выполнения функции fib: 4.829998943023384e-07
#
# Время выполнения функции fib: 4.6000059228390455e-07
#
# Время выполнения функции fib: 4.4699936552206054e-07
#
# Время выполнения функции fib: 5.237499954091618e-05
#
# Время выполнения функции fib: 0.00010621900037222076
#
# Время выполнения функции fib: 0.00020860699987679254
#
# Время выполнения функции fib: 4.549992809188552e-07
#
# Время выполнения функции fib: 8.870001693139784e-07
#
# Время выполнения функции fib: 7.159997039707378e-07
#
# Время выполнения функции fib: 7.36600004529464e-05
#
# Время выполнения функции fib: 0.06399005200000829
#
# Время выполнения функции fib: 4.290004653739743e-07
#
# Время выполнения функции fib: 4.049998096888885e-07
#
# Время выполнения функции fib: 4.60600003862055e-05
#
# Время выполнения функции fib: 4.029998308396898e-07
#
# Время выполнения функции fib: 7.839998943381943e-07
#
# Время выполнения функции fib: 4.249995981808752e-07
#
# Время выполнения функции fib: 3.3677999454084784e-05
#
# Время выполнения функции fib: 6.455699985963292e-05
#
# Время выполнения функции fib: 0.00014168999950925354
#
# Время выполнения функции fib: 0.06416349200026161
#
# Время выполнения функции fib: 0.0644255589995737
#
# Время выполнения функции fib: 5.129995770403184e-07
#
# Время выполнения функции fib: 4.7399953473359346e-07
#
# Время выполнения функции fib: 4.060002538608387e-07
#
# Время выполнения функции fib: 3.3663000067463145e-05
#
# Время выполнения функции fib: 8.360399988305289e-05
#
# Время выполнения функции fib: 4.189996616332792e-07
#
# Время выполнения функции fib: 3.6299934436101466e-07
#
# Время выполнения функции fib: 3.079799989791354e-05
#
# Время выполнения функции fib: 4.779994924319908e-07
#
# Время выполнения функции fib: 6.039999789209105e-07
#
# Время выполнения функции fib: 3.80000528821256e-07
#
# Время выполнения функции fib: 3.087900040554814e-05
#
# Время выполнения функции fib: 6.287300038820831e-05
#
# Время выполнения функции fib: 0.00012520499967649812
#
# Время выполнения функции fib: 0.0002404649994787178
#
# Время выполнения функции fib: 5.500005499925464e-07
#
# Время выполнения функции fib: 4.1299972508568317e-07
#
# Время выполнения функции fib: 3.1568999474984594e-05
#
# Время выполнения функции fib: 4.2699957703007385e-07
#
# Время выполнения функции fib: 4.459998308448121e-07
#
# Время выполнения функции fib: 4.3100044422317296e-07
#
# Время выполнения функции fib: 3.278700023656711e-05
#
# Время выполнения функции fib: 6.502500036731362e-05
#
# Время выполнения функции fib: 0.00012857899946538964
#
# Время выполнения функции fib: 5.040001269662753e-07
#
# Время выполнения функции fib: 3.9799942896934226e-07
#
# Время выполнения функции fib: 4.180001269560307e-07
#
# Время выполнения функции fib: 3.252200076531153e-05
#
# Время выполнения функции fib: 6.51360005576862e-05
#
# Время выполнения функции fib: 4.700004865298979e-07
#
# Время выполнения функции fib: 4.980001904186793e-07
#
# Время выполнения функции fib: 3.4981000681000296e-05
#
# Время выполнения функции fib: 5.149995558895171e-07
#
# Время выполнения функции fib: 6.959999154787511e-07
#
# Время выполнения функции fib: 4.3700038077076897e-07
#
# Время выполнения функции fib: 3.526899945427431e-05
#
# Время выполнения функции fib: 6.952199964871397e-05
#
# Время выполнения функции fib: 0.00013807899995299522
#
# Время выполнения функции fib: 0.00023618300019734306
#
# Время выполнения функции fib: 0.00039698599994153483
#
# Время выполнения функции fib: 0.000670293999974092
#
# Время выполнения функции fib: 0.06512893599938252
#
# Время выполнения функции fib: 5.100000635138713e-07
#
# Время выполнения функции fib: 5.219999366090633e-07
#
# Время выполнения функции fib: 4.980001904186793e-07
#
# Время выполнения функции fib: 3.406999985600123e-05
#
# Время выполнения функции fib: 6.759200005035382e-05
#
# Время выполнения функции fib: 5.040001269662753e-07
#
# Время выполнения функции fib: 9.688000318419654e-06
#
# Время выполнения функции fib: 4.3296000512782484e-05
#
# Время выполнения функции fib: 4.810008249478415e-07
#
# Время выполнения функции fib: 5.029996827943251e-07
#
# Время выполнения функции fib: 3.879995347233489e-07
#
# Время выполнения функции fib: 3.382100021553924e-05
#
# Время выполнения функции fib: 6.647199916187674e-05
#
# Время выполнения функции fib: 0.00014231600016501034
#
# Время выполнения функции fib: 0.00024164700062101474
#
# Время выполнения функции fib: 5.029996827943251e-07
#
# Время выполнения функции fib: 3.959994501201436e-07
#
# Время выполнения функции fib: 3.204600034223404e-05
#
# Время выполнения функции fib: 5.019992386223748e-07
#
# Время выполнения функции fib: 7.099997674231417e-07
#
# Время выполнения функции fib: 4.880002961726859e-07
#
# Время выполнения функции fib: 3.73780003428692e-05
#
# Время выполнения функции fib: 9.154500003205612e-05
#
# Время выполнения функции fib: 0.00015699399955337867
#
# Время выполнения функции fib: 5.080000846646726e-07
#
# Время выполнения функции fib: 4.0699978853808716e-07
#
# Время выполнения функции fib: 4.67000063508749e-07
#
# Время выполнения функции fib: 3.374299922143109e-05
#
# Время выполнения функции fib: 6.693399973300984e-05
#
# Время выполнения функции fib: 5.070005499874242e-07
#
# Время выполнения функции fib: 9.099994713324122e-07
#
# Время выполнения функции fib: 4.054399960295996e-05
#
# Время выполнения функции fib: 5.039992174715735e-07
#
# Время выполнения функции fib: 7.380003808066249e-07
#
# Время выполнения функции fib: 4.1499970393488184e-07
#
# Время выполнения функции fib: 3.211799958080519e-05
#
# Время выполнения функции fib: 6.437199954234529e-05
#
# Время выполнения функции fib: 0.00013840399969922146
#
# Время выполнения функции fib: 0.000238359999457316
#
# Время выполнения функции fib: 0.0004273230006219819
#
# Время выполнения функции fib: 0.00070125399997778
#
# Время выполнения функции fib: 5.160000000614673e-07
#
# Время выполнения функции fib: 4.809999154531397e-07
#
# Время выполнения функции fib: 3.4159999813709874e-05
#
# Время выполнения функции fib: 5.060001058154739e-07
#
# Время выполнения функции fib: 5.209994924371131e-07
#
# Время выполнения функции fib: 4.6300010581035167e-07
#
# Время выполнения функции fib: 3.338499936944572e-05
#
# Время выполнения функции fib: 6.647999998676823e-05
#
# Время выполнения функции fib: 0.0001321320005445159
#
# Время выполнения функции fib: 3.4599997889017686e-07
#
# Время выполнения функции fib: 4.029998308396898e-07
#
# Время выполнения функции fib: 4.3299951357766986e-07
#
# Время выполнения функции fib: 3.107799966528546e-05
#
# Время выполнения функции fib: 6.255500011320692e-05
#
# Время выполнения функции fib: 4.180001269560307e-07
#
# Время выполнения функции fib: 3.559998731361702e-07
#
# Время выполнения функции fib: 0.00117476700052066
#
# Время выполнения функции fib: 7.049993655527942e-07
#
# Время выполнения функции fib: 8.110000635497272e-07
#
# Время выполнения функции fib: 5.110005076858215e-07
#
# Время выполнения функции fib: 3.625000044849003e-05
#
# Время выполнения функции fib: 7.953000022098422e-05
#
# Время выполнения функции fib: 0.001326028000221413
#
# Время выполнения функции fib: 0.0014207149997673696
#
# Время выполнения функции fib: 0.0016161909998118063
#
# Время выполнения функции fib: 5.010006134398282e-07
#
# Время выполнения функции fib: 5.410001904238015e-07
#
# Время выполнения функции fib: 4.959993020747788e-07
#
# Время выполнения функции fib: 3.3973999961744994e-05
#
# Время выполнения функции fib: 6.798799950047396e-05
#
# Время выполнения функции fib: 5.060001058154739e-07
#
# Время выполнения функции fib: 4.7100002120714635e-07
#
# Время выполнения функции fib: 3.331500010972377e-05
#
# Время выполнения функции fib: 4.55000190413557e-07
#
# Время выполнения функции fib: 8.429997251369059e-07
#
# Время выполнения функции fib: 6.020000000717118e-07
#
# Время выполнения функции fib: 5.832899933011504e-05
#
# Время выполнения функции fib: 0.0027872969994859886
#
# Время выполнения функции fib: 0.002852770000572491
#
# Время выполнения функции fib: 0.002976220999698853
#
# Время выполнения функции fib: 4.869998520007357e-07
#
# Время выполнения функции fib: 4.67000063508749e-07
#
# Время выполнения функции fib: 3.380899943294935e-05
#
# Время выполнения функции fib: 4.67000063508749e-07
#
# Время выполнения функции fib: 5.010006134398282e-07
#
# Время выполнения функции fib: 4.3900035961996764e-07
#
# Время выполнения функции fib: 3.27179996020277e-05
#
# Время выполнения функции fib: 6.468999981734669e-05
#
# Время выполнения функции fib: 0.00012960200001543853
#
# Время выполнения функции fib: 4.769999577547424e-07
#
# Время выполнения функции fib: 4.879993866779841e-07
#
# Время выполнения функции fib: 4.319999789004214e-07
#
# Время выполнения функции fib: 3.7914000131422654e-05
#
# Время выполнения функции fib: 7.565299983980367e-05
#
# Время выполнения функции fib: 4.989997250959277e-07
#
# Время выполнения функции fib: 4.4600074033951387e-07
#
# Время выполнения функции fib: 3.2482000278832857e-05
#
# Время выполнения функции fib: 4.7399953473359346e-07
#
# Время выполнения функции fib: 7.430007826769724e-07
#
# Время выполнения функции fib: 4.1900057112798095e-07
#
# Время выполнения функции fib: 3.2468999961565714e-05
#
# Время выполнения функции fib: 6.354899960570037e-05
#
# Время выполнения функции fib: 0.00012745599997288082
#
# Время выполнения функции fib: 0.0002334279997739941
#
# Время выполнения функции fib: 0.00039295199985645013
#
# Время выполнения функции fib: 0.0034029379994535702
#
# Время выполнения функции fib: 0.005053750000115542
#
# Время выполнения функции fib: 0.005798958000013954
#
# Время выполнения функции fib: 0.070960823999485
#
# Время выполнения функции fib: 4.599996827892028e-07
#
# Время выполнения функции fib: 4.700004865298979e-07
#
# Время выполнения функции fib: 4.470002750167623e-07
#
# Время выполнения функции fib: 3.144800029986072e-05
#
# Время выполнения функции fib: 6.355200002872152e-05
#
# Время выполнения функции fib: 4.5900014811195433e-07
#
# Время выполнения функции fib: 4.379999154480174e-07
#
# Время выполнения функции fib: 3.673999981401721e-05
#
# Время выполнения функции fib: 4.910007191938348e-07
#
# Время выполнения функции fib: 4.940002327202819e-07
#
# Время выполнения функции fib: 4.500006980379112e-07
#
# Время выполнения функции fib: 3.230499987694202e-05
#
# Время выполнения функции fib: 6.35880005575018e-05
#
# Время выполнения функции fib: 0.0001308290002270951
#
# Время выполнения функции fib: 0.00022469399937108392
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 4.4199987314641476e-07
#
# Время выполнения функции fib: 3.1757000215293374e-05
#
# Время выполнения функции fib: 4.620005711331032e-07
#
# Время выполнения функции fib: 4.5700016926275566e-07
#
# Время выполнения функции fib: 4.0699978853808716e-07
#
# Время выполнения функции fib: 3.228500008845003e-05
#
# Время выполнения функции fib: 6.5134000578837e-05
#
# Время выполнения функции fib: 0.00012744499963446287
#
# Время выполнения функции fib: 4.43000317318365e-07
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 4.319999789004214e-07
#
# Время выполнения функции fib: 3.098199977102922e-05
#
# Время выполнения функции fib: 6.166000002849614e-05
#
# Время выполнения функции fib: 4.5700016926275566e-07
#
# Время выполнения функции fib: 4.549992809188552e-07
#
# Время выполнения функции fib: 4.583000009006355e-05
#
# Время выполнения функции fib: 4.5100023271515965e-07
#
# Время выполнения функции fib: 4.779994924319908e-07
#
# Время выполнения функции fib: 4.2500050767557696e-07
#
# Время выполнения функции fib: 3.188299979228759e-05
#
# Время выполнения функции fib: 6.371400013449602e-05
#
# Время выполнения функции fib: 0.00014061499950912548
#
# Время выполнения функции fib: 0.00023248699926625704
#
# Время выполнения функции fib: 0.0003896769994753413
#
# Время выполнения функции fib: 0.000644423999801802
#
# Время выполнения функции fib: 4.5400065573630854e-07
#
# Время выполнения функции fib: 4.2599913285812363e-07
#
# Время выполнения функции fib: 3.351699979248224e-05
#
# Время выполнения функции fib: 4.779994924319908e-07
#
# Время выполнения функции fib: 4.6199966163840145e-07
#
# Время выполнения функции fib: 4.339999577496201e-07
#
# Время выполнения функции fib: 3.2160000046133064e-05
#
# Время выполнения функции fib: 8.424600036960328e-05
#
# Время выполнения функции fib: 0.00014845599980617408
#
# Время выполнения функции fib: 4.459998308448121e-07
#
# Время выполнения функции fib: 4.73000000056345e-07
#
# Время выполнения функции fib: 4.5900014811195433e-07
#
# Время выполнения функции fib: 3.1120000130613334e-05
#
# Время выполнения функции fib: 6.163200032460736e-05
#
# Время выполнения функции fib: 5.000001692678779e-07
#
# Время выполнения функции fib: 4.399998942972161e-07
#
# Время выполнения функции fib: 3.1118999686441384e-05
#
# Время выполнения функции fib: 4.55000190413557e-07
#
# Время выполнения функции fib: 4.5400065573630854e-07
#
# Время выполнения функции fib: 4.120001904084347e-07
#
# Время выполнения функции fib: 3.0993000109447166e-05
#
# Время выполнения функции fib: 6.126999960542889e-05
#
# Время выполнения функции fib: 0.00017884899989439873
#
# Время выполнения функции fib: 0.0002709849995881086
#
# Время выполнения функции fib: 0.00044962300034967484
#
# Время выполнения функции fib: 4.5900014811195433e-07
#
# Время выполнения функции fib: 4.820003596250899e-07
#
# Время выполнения функции fib: 4.4600074033951387e-07
#
# Время выполнения функции fib: 3.1490999390371144e-05
#
# Время выполнения функции fib: 6.307200055744033e-05
#
# Время выполнения функции fib: 4.4800071918871254e-07
#
# Время выполнения функции fib: 4.1300063458038494e-07
#
# Время выполнения функции fib: 3.210500017303275e-05
#
# Время выполнения функции fib: 4.350004019215703e-07
#
# Время выполнения функции fib: 4.67000063508749e-07
#
# Время выполнения функции fib: 4.229996193316765e-07
#
# Время выполнения функции fib: 3.204400036338484e-05
#
# Время выполнения функции fib: 6.990699966991087e-05
#
# Время выполнения функции fib: 0.00013261699950817274
#
# Время выполнения функции fib: 0.00022649800030194456
#
# Время выполнения функции fib: 4.509993232204579e-07
#
# Время выполнения функции fib: 4.1300063458038494e-07
#
# Время выполнения функции fib: 3.1429999580723234e-05
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 4.5599972509080544e-07
#
# Время выполнения функции fib: 4.199991963105276e-07
#
# Время выполнения функции fib: 3.147300049022306e-05
#
# Время выполнения функции fib: 6.224399930943036e-05
#
# Время выполнения функции fib: 0.0001433709994671517
#
# Время выполнения функции fib: 4.599996827892028e-07
#
# Время выполнения функции fib: 4.869998520007357e-07
#
# Время выполнения функции fib: 4.4099942897446454e-07
#
# Время выполнения функции fib: 3.162300072290236e-05
#
# Время выполнения функции fib: 6.308199954219162e-05
#
# Время выполнения функции fib: 4.470002750167623e-07
#
# Время выполнения функции fib: 4.4099942897446454e-07
#
# Время выполнения функции fib: 3.355699936946621e-05
#
# Время выполнения функции fib: 4.5599972509080544e-07
#
# Время выполнения функции fib: 6.870004654047079e-07
#
# Время выполнения функции fib: 4.449993866728619e-07
#
# Время выполнения функции fib: 3.227500019420404e-05
#
# Время выполнения функции fib: 6.322900026134448e-05
#
# Время выполнения функции fib: 0.0001326199999311939
#
# Время выполнения функции fib: 0.00022610899941355456
#
# Время выполнения функции fib: 0.0004003829999419395
#
# Время выполнения функции fib: 0.0006578339998668525
#
# Время выполнения функции fib: 0.001137870000093244
#
# Время выполнения функции fib: 0.0018137699998987955
#
# Время выполнения функции fib: 4.6199966163840145e-07
#
# Время выполнения функции fib: 4.1299972508568317e-07
#
# Время выполнения функции fib: 3.1909000426821876e-05
#
# Время выполнения функции fib: 4.2099964048247784e-07
#
# Время выполнения функции fib: 4.5900014811195433e-07
#
# Время выполнения функции fib: 4.260000423528254e-07
#
# Время выполнения функции fib: 3.223100065952167e-05
#
# Время выполнения функции fib: 6.35859996691579e-05
#
# Время выполнения функции fib: 0.00012615200012078276
#
# Время выполнения функции fib: 4.319999789004214e-07
#
# Время выполнения функции fib: 4.459998308448121e-07
#
# Время выполнения функции fib: 3.970008037867956e-07
#
# Время выполнения функции fib: 3.07910004266887e-05
#
# Время выполнения функции fib: 6.166200000734534e-05
#
# Время выполнения функции fib: 4.6300010581035167e-07
#
# Время выполнения функции fib: 3.9999940781854093e-07
#
# Время выполнения функции fib: 3.292299970780732e-05
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 4.67000063508749e-07
#
# Время выполнения функции fib: 4.0200029616244137e-07
#
# Время выполнения функции fib: 3.11759995383909e-05
#
# Время выполнения функции fib: 6.2036000599619e-05
#
# Время выполнения функции fib: 0.00012517499999376014
#
# Время выполнения функции fib: 0.0002165219993912615
#
# Время выполнения функции fib: 0.00037224900006549433
#
# Время выполнения функции fib: 4.4199987314641476e-07
#
# Время выполнения функции fib: 4.6199966163840145e-07
#
# Время выполнения функции fib: 4.3000000005122274e-07
#
# Время выполнения функции fib: 3.22599998980877e-05
#
# Время выполнения функции fib: 6.3429999499931e-05
#
# Время выполнения функции fib: 4.5900014811195433e-07
#
# Время выполнения функции fib: 4.2099964048247784e-07
#
# Время выполнения функции fib: 3.131099947495386e-05
#
# Время выполнения функции fib: 4.49000253865961e-07
#
# Время выполнения функции fib: 4.620005711331032e-07
#
# Время выполнения функции fib: 3.9200040191644803e-07
#
# Время выполнения функции fib: 3.07910004266887e-05
#
# Время выполнения функции fib: 6.131500049377792e-05
#
# Время выполнения функции fib: 0.00012289999995118706
#
# Время выполнения функции fib: 0.00021625800036417786
#
# Время выполнения функции fib: 4.67000063508749e-07
#
# Время выполнения функции fib: 4.0899976738728583e-07
#
# Время выполнения функции fib: 0.0043250119997537695
#
# Время выполнения функции fib: 6.010004653944634e-07
#
# Время выполнения функции fib: 6.199998097144999e-07
#
# Время выполнения функции fib: 5.040001269662753e-07
#
# Время выполнения функции fib: 3.399799970793538e-05
#
# Время выполнения функции fib: 7.399899914162233e-05
#
# Время выполнения функции fib: 0.004458002999854216
#
# Время выполнения функции fib: 4.4199987314641476e-07
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 5.030005922890268e-07
#
# Время выполнения функции fib: 5.4707999879610725e-05
#
# Время выполнения функции fib: 8.663600056024734e-05
#
# Время выполнения функции fib: 4.379999154480174e-07
#
# Время выполнения функции fib: 4.189996616332792e-07
#
# Время выполнения функции fib: 3.198100057488773e-05
#
# Время выполнения функции fib: 4.6799959818599746e-07
#
# Время выполнения функции fib: 6.279997251112945e-07
#
# Время выполнения функции fib: 4.339999577496201e-07
#
# Время выполнения функции fib: 3.253299928474007e-05
#
# Время выполнения функции fib: 6.338399998639943e-05
#
# Время выполнения функции fib: 0.000125551000564883
#
# Время выполнения функции fib: 0.00024244199994427618
#
# Время выполнения функции fib: 0.004731284000627056
#
# Время выполнения функции fib: 0.004977212999619951
#
# Время выполнения функции fib: 0.005379103999985091
#
# Время выполнения функции fib: 4.2699957703007385e-07
#
# Время выполнения функции fib: 4.3000000005122274e-07
#
# Время выполнения функции fib: 4.2200008465442806e-07
#
# Время выполнения функции fib: 3.19540004056762e-05
#
# Время выполнения функции fib: 6.444099926739e-05
#
# Время выполнения функции fib: 4.4199987314641476e-07
#
# Время выполнения функции fib: 4.029998308396898e-07
#
# Время выполнения функции fib: 5.0552000175230205e-05
#
# Время выполнения функции fib: 4.4199987314641476e-07
#
# Время выполнения функции fib: 4.2699957703007385e-07
#
# Время выполнения функции fib: 4.3499949242686853e-07
#
# Время выполнения функции fib: 3.156400089210365e-05
#
# Время выполнения функции fib: 6.2647999584442e-05
#
# Время выполнения функции fib: 0.0001448699995307834
#
# Время выполнения функции fib: 0.0002398670003458392
#
# Время выполнения функции fib: 4.4799980969401076e-07
#
# Время выполнения функции fib: 4.369994712760672e-07
#
# Время выполнения функции fib: 3.2998000278894324e-05
#
# Время выполнения функции fib: 4.189996616332792e-07
#
# Время выполнения функции fib: 4.4799980969401076e-07
#
# Время выполнения функции fib: 4.640005499823019e-07
#
# Время выполнения функции fib: 5.626800066238502e-05
#
# Время выполнения функции fib: 8.744600017962512e-05
#
# Время выполнения функции fib: 0.00015139199967961758
#
# Время выполнения функции fib: 4.200001058052294e-07
#
# Время выполнения функции fib: 4.3499949242686853e-07
#
# Время выполнения функции fib: 4.0700069803278893e-07
#
# Время выполнения функции fib: 3.158900017297128e-05
#
# Время выполнения функции fib: 7.329500022024149e-05
#
# Время выполнения функции fib: 4.440007614903152e-07
#
# Время выполнения функции fib: 4.1000021155923605e-07
#
# Время выполнения функции fib: 3.1739000405650586e-05
#
# Время выполнения функции fib: 4.2200008465442806e-07
#
# Время выполнения функции fib: 4.369994712760672e-07
#
# Время выполнения функции fib: 4.1499970393488184e-07
#
# Время выполнения функции fib: 3.1554000088362955e-05
#
# Время выполнения функции fib: 6.294000013440382e-05
#
# Время выполнения функции fib: 0.00012542600052256603
#
# Время выполнения функции fib: 0.0002292950002811267
#
# Время выполнения функции fib: 0.00041045200032385765
#
# Время выполнения функции fib: 0.0006928929997229716
#
# Время выполнения функции fib: 4.249995981808752e-07
#
# Время выполнения функции fib: 4.060002538608387e-07
#
# Время выполнения функции fib: 3.369699970789952e-05
#
# Время выполнения функции fib: 4.2400006350362673e-07
#
# Время выполнения функции fib: 4.3599993659881875e-07
#
# Время выполнения функции fib: 4.080002327100374e-07
#
# Время выполнения функции fib: 3.110399939032504e-05
#
# Время выполнения функции fib: 0.004157653999754984
#
# Время выполнения функции fib: 0.004230385000482784
#
# Время выполнения функции fib: 5.149995558895171e-07
#
# Время выполнения функции fib: 6.489999577752315e-07
#
# Время выполнения функции fib: 4.950006768922321e-07
#
# Время выполнения функции fib: 3.302899949630955e-05
#
# Время выполнения функции fib: 6.903900066390634e-05
#
# Время выполнения функции fib: 4.73000000056345e-07
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 3.192300027876627e-05
#
# Время выполнения функции fib: 4.309995347284712e-07
#
# Время выполнения функции fib: 5.570000212173909e-07
#
# Время выполнения функции fib: 4.3100044422317296e-07
#
# Время выполнения функции fib: 3.1444999876839574e-05
#
# Время выполнения функции fib: 6.176099941512803e-05
#
# Время выполнения функции fib: 0.00012380399948597187
#
# Время выполнения функции fib: 0.00022515000000566943
#
# Время выполнения функции fib: 0.004487686000175017
#
# Время выполнения функции fib: 5.490001058205962e-07
#
# Время выполнения функции fib: 4.1299972508568317e-07
#
# Время выполнения функции fib: 3.5699940781341866e-07
#
# Время выполнения функции fib: 4.815200009034015e-05
#
# Время выполнения функции fib: 8.370900013687788e-05
#
# Время выполнения функции fib: 4.169996827840805e-07
#
# Время выполнения функции fib: 4.929997885483317e-07
#
# Время выполнения функции fib: 3.5365999792702496e-05
#
# Время выполнения функции fib: 4.5399974624160677e-07
#
# Время выполнения функции fib: 4.049998096888885e-07
#
# Время выполнения функции fib: 4.5700016926275566e-07
#
# Время выполнения функции fib: 3.3088999771280214e-05
#
# Время выполнения функции fib: 6.633900011365768e-05
#
# Время выполнения функции fib: 0.00013418299931799993
#
# Время выполнения функции fib: 0.00025022199952218216
#
# Время выполнения функции fib: 4.639996404876001e-07
#
# Время выполнения функции fib: 4.470002750167623e-07
#
# Время выполнения функции fib: 4.0795999666443095e-05
#
# Время выполнения функции fib: 4.520006768871099e-07
#
# Время выполнения функции fib: 4.749999789055437e-07
#
# Время выполнения функции fib: 4.2800002120202407e-07
#
# Время выполнения функции fib: 3.1642999601899646e-05
#
# Время выполнения функции fib: 6.322999979602173e-05
#
# Время выполнения функции fib: 0.0001352419994873344
#
# Время выполнения функции fib: 4.61000126961153e-07
#
# Время выполнения функции fib: 4.860003173234873e-07
#
# Время выполнения функции fib: 4.449993866728619e-07
#
# Время выполнения функции fib: 3.145800019410672e-05
#
# Время выполнения функции fib: 6.256100004975451e-05
#
# Время выполнения функции fib: 4.640005499823019e-07
#
# Время выполнения функции fib: 4.1900057112798095e-07
#
# Время выполнения функции fib: 3.089099936914863e-05
#
# Время выполнения функции fib: 4.579997039400041e-07
#
# Время выполнения функции fib: 7.440003173542209e-07
#
# Время выполнения функции fib: 4.1499970393488184e-07
#
# Время выполнения функции fib: 3.170600029989146e-05
#
# Время выполнения функции fib: 6.237700017663883e-05
#
# Время выполнения функции fib: 0.00012340699959167978
#
# Время выполнения функции fib: 0.00021589100015262375
#
# Время выполнения функции fib: 0.00038102100006653927
#
# Время выполнения функции fib: 0.0006614009998884285
#
# Время выполнения функции fib: 0.005179687999770977
#
# Время выполнения функции fib: 0.005902343999878212
#
# Время выполнения функции fib: 0.011311498999930336
#
# Время выполнения функции fib: 0.01315609300036158
#
# Время выполнения функции fib: 0.08414869500029454
#
# Время выполнения функции fib: 0.1852436539993505
#
# Время выполнения функции fib: 0.21094484300010663
#
# Время выполнения функции fib: 3.819995981757529e-07
#
# Время выполнения функции fib: 4.569992597680539e-07
#
# Время выполнения функции fib: 4.690000423579477e-07
#
# Время выполнения функции fib: 4.131500008952571e-05
#
# Время выполнения функции fib: 7.296400053746765e-05
#
# Время выполнения функции fib: 4.7100002120714635e-07
#
# Время выполнения функции fib: 4.260000423528254e-07
#
# Время выполнения функции fib: 3.261799975007307e-05
#
# Время выполнения функции fib: 4.4500029616756365e-07
#
# Время выполнения функции fib: 4.73000000056345e-07
#
# Время выполнения функции fib: 4.230005288263783e-07
#
# Время выполнения функции fib: 3.152499994030222e-05
#
# Время выполнения функции fib: 6.28139996479149e-05
#
# Время выполнения функции fib: 0.00012582999988808297
#
# Время выполнения функции fib: 0.00022905500009073876
#
# Время выполнения функции fib: 4.659996193367988e-07
#
# Время выполнения функции fib: 4.6799959818599746e-07
#
# Время выполнения функции fib: 4.653100040741265e-05
#
# Время выполнения функции fib: 4.5399974624160677e-07
#
# Время выполнения функции fib: 4.78999936603941e-07
#
# Время выполнения функции fib: 4.2200008465442806e-07
#
# Время выполнения функции fib: 3.2435999855806585e-05
#
# Время выполнения функции fib: 6.415000007109484e-05
#
# Время выполнения функции fib: 0.00014154099972074619
#
# Время выполнения функции fib: 4.749999789055437e-07
#
# Время выполнения функции fib: 5.23999915458262e-07
#
# Время выполнения функции fib: 4.5700016926275566e-07
#
# Время выполнения функции fib: 3.2234000173048116e-05
#
# Время выполнения функции fib: 6.369000038830563e-05
#
# Время выполнения функции fib: 4.749999789055437e-07
#
# Время выполнения функции fib: 4.2400006350362673e-07
#
# Время выполнения функции fib: 3.847600055451039e-05
#
# Время выполнения функции fib: 4.7399953473359346e-07
#
# Время выполнения функции fib: 4.659996193367988e-07
#
# Время выполнения функции fib: 4.290004653739743e-07
#
# Время выполнения функции fib: 3.231800019420916e-05
#
# Время выполнения функции fib: 6.390300040948205e-05
#
# Время выполнения функции fib: 0.0001327679992755293
#
# Время выполнения функции fib: 0.0002284279999003047
#
# Время выполнения функции fib: 0.00040143399928638246
#
# Время выполнения функции fib: 0.0006607549994441797
#
# Время выполнения функции fib: 4.809999154531397e-07
#
# Время выполнения функции fib: 4.3000000005122274e-07
#
# Время выполнения функции fib: 3.131199991912581e-05
#
# Время выполнения функции fib: 4.5100023271515965e-07
#
# Время выполнения функции fib: 4.6300010581035167e-07
#
# Время выполнения функции fib: 4.270004865247756e-07
#
# Время выполнения функции fib: 3.1910000870993827e-05
#
# Время выполнения функции fib: 6.269000004976988e-05
#
# Время выполнения функции fib: 0.00020127599964325782
#
# Время выполнения функции fib: 4.579997039400041e-07
#
# Время выполнения функции fib: 4.690000423579477e-07
#
# Время выполнения функции fib: 4.290004653739743e-07
#
# Время выполнения функции fib: 3.162400025757961e-05
#
# Время выполнения функции fib: 6.274899988056859e-05
#
# Время выполнения функции fib: 4.690000423579477e-07
#
# Время выполнения функции fib: 4.369994712760672e-07
#
# Время выполнения функции fib: 3.150100019411184e-05
#
# Время выполнения функции fib: 4.6500008465955034e-07
#
# Время выполнения функции fib: 5.580004653893411e-07
#
# Время выполнения функции fib: 4.260000423528254e-07
#
# Время выполнения функции fib: 3.117699998256285e-05
#
# Время выполнения функции fib: 6.41959995846264e-05
#
# Время выполнения функции fib: 0.00012648199935938464
#
# Время выполнения функции fib: 0.00021959700006846106
#
# Время выполнения функции fib: 0.00045146499996917555
#
# Время выполнения функции fib: 4.339999577496201e-07
#
# Время выполнения функции fib: 4.5399974624160677e-07
#
# Время выполнения функции fib: 4.3000000005122274e-07
#
# Время выполнения функции fib: 3.146600010950351e-05
#
# Время выполнения функции fib: 6.255100015550852e-05
#
# Время выполнения функции fib: 4.749999789055437e-07
#
# Время выполнения функции fib: 4.229996193316765e-07
#
# Время выполнения функции fib: 3.122199996141717e-05
#
# Время выполнения функции fib: 4.530002115643583e-07
#
# Время выполнения функции fib: 4.4800071918871254e-07
#
# Время выполнения функции fib: 3.759996616281569e-07
#
# Время выполнения функции fib: 3.1522999961453024e-05
#
# Время выполнения функции fib: 6.28910001978511e-05
#
# Время выполнения функции fib: 0.00013596400003734743
#
# Время выполнения функции fib: 0.00022902199998497963
#
# Время выполнения функции fib: 4.779994924319908e-07
#
# Время выполнения функции fib: 4.290004653739743e-07
#
# Время выполнения функции fib: 3.1243000194081105e-05
#
# Время выполнения функции fib: 4.3700038077076897e-07
#
# Время выполнения функции fib: 4.90999809699133e-07
#
# Время выполнения функции fib: 4.0200029616244137e-07
#
# Время выполнения функции fib: 3.222400027880212e-05
#
# Время выполнения функции fib: 6.398799996532034e-05
#
# Время выполнения функции fib: 0.00013168100031180074
#
# Время выполнения функции fib: 4.440007614903152e-07
#
# Время выполнения функции fib: 4.6499917516484857e-07
#
# Время выполнения функции fib: 4.180001269560307e-07
#
# Время выполнения функции fib: 3.137800013064407e-05
#
# Время выполнения функции fib: 6.232299983821576e-05
#
# Время выполнения функции fib: 4.640005499823019e-07
#
# Время выполнения функции fib: 4.079993232153356e-07
#
# Время выполнения функции fib: 3.1629999284632504e-05
#
# Время выполнения функции fib: 4.500006980379112e-07
#
# Время выполнения функции fib: 4.6300010581035167e-07
#
# Время выполнения функции fib: 4.0200029616244137e-07
#
# Время выполнения функции fib: 3.1861999559623655e-05
#
# Время выполнения функции fib: 6.288599979598075e-05
#
# Время выполнения функции fib: 0.00012647400035348255
#
# Время выполнения функции fib: 0.0002192029996876954
#
# Время выполнения функции fib: 0.0003806199993050541
#
# Время выполнения функции fib: 0.0006399189996955101
#
# Время выполнения функции fib: 0.0011214159994779038
#
# Время выполнения функции fib: 0.0018118099997082027
#
# Время выполнения функции fib: 4.61000126961153e-07
#
# Время выполнения функции fib: 4.169996827840805e-07
#
# Время выполнения функции fib: 3.20290000672685e-05
#
# Время выполнения функции fib: 4.55000190413557e-07
#
# Время выполнения функции fib: 4.709991117124446e-07
#
# Время выполнения функции fib: 4.229996193316765e-07
#
# Время выполнения функции fib: 3.149499934806954e-05
#
# Время выполнения функции fib: 6.243200004973914e-05
#
# Время выполнения функции fib: 0.00012473300012061372
#
# Время выполнения функции fib: 4.4799980969401076e-07
#
# Время выполнения функции fib: 4.659996193367988e-07
#
# Время выполнения функции fib: 4.2400006350362673e-07
#
# Время выполнения функции fib: 3.1924999348120764e-05
#
# Время выполнения функции fib: 6.290799956332194e-05
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 3.909999577444978e-07
#
# Время выполнения функции fib: 3.1569999919156544e-05
#
# Время выполнения функции fib: 4.410003384691663e-07
#
# Время выполнения функции fib: 4.520006768871099e-07
#
# Время выполнения функции fib: 4.0200029616244137e-07
#
# Время выполнения функции fib: 3.1554000088362955e-05
#
# Время выполнения функции fib: 6.256399956328096e-05
#
# Время выполнения функции fib: 0.00012488100037444383
#
# Время выполнения функции fib: 0.00021739499970863108
#
# Время выполнения функции fib: 0.0003719610003827256
#
# Время выполнения функции fib: 4.470002750167623e-07
#
# Время выполнения функции fib: 4.749999789055437e-07
#
# Время выполнения функции fib: 4.0699978853808716e-07
#
# Время выполнения функции fib: 4.182900011073798e-05
#
# Время выполнения функции fib: 7.419799931085436e-05
#
# Время выполнения функции fib: 4.61000126961153e-07
#
# Время выполнения функции fib: 4.1499970393488184e-07
#
# Время выполнения функции fib: 3.177500002493616e-05
#
# Время выполнения функции fib: 4.339999577496201e-07
#
# Время выполнения функции fib: 4.61000126961153e-07
#
# Время выполнения функции fib: 4.060002538608387e-07
#
# Время выполнения функции fib: 3.170000036334386e-05
#
# Время выполнения функции fib: 6.240800030354876e-05
#
# Время выполнения функции fib: 0.0001249269998879754
#
# Время выполнения функции fib: 0.00022943000021768967
#
# Время выполнения функции fib: 4.5700016926275566e-07
#
# Время выполнения функции fib: 4.2400006350362673e-07
#
# Время выполнения функции fib: 3.177600046910811e-05
#
# Время выполнения функции fib: 4.61000126961153e-07
#
# Время выполнения функции fib: 4.4500029616756365e-07
#
# Время выполнения функции fib: 4.140001692576334e-07
#
# Время выполнения функции fib: 3.133300015178975e-05
#
# Время выполнения функции fib: 6.243400002858834e-05
#
# Время выполнения функции fib: 0.00013022500024817418
#
# Время выполнения функции fib: 4.3899945012526587e-07
#
# Время выполнения функции fib: 4.560006345855072e-07
#
# Время выполнения функции fib: 4.109997462364845e-07
#
# Время выполнения функции fib: 3.1394999496114906e-05
#
# Время выполнения функции fib: 6.261800081119873e-05
#
# Время выполнения функции fib: 4.500006980379112e-07
#
# Время выполнения функции fib: 4.2099964048247784e-07
#
# Время выполнения функции fib: 3.235199983464554e-05
#
# Время выполнения функции fib: 4.3899945012526587e-07
#
# Время выполнения функции fib: 4.4500029616756365e-07
#
# Время выполнения функции fib: 4.0399936551693827e-07
#
# Время выполнения функции fib: 3.174199991917703e-05
#
# Время выполнения функции fib: 6.30329996056389e-05
#
# Время выполнения функции fib: 0.0001784530004442786
#
# Время выполнения функции fib: 0.0002719140002227505
#
# Время выполнения функции fib: 0.0004320210000514635
#
# Время выполнения функции fib: 0.0006911970003784518
#
# Время выполнения функции fib: 0.0010926269997071358
#
# Время выполнения функции fib: 4.309995347284712e-07
#
# Время выполнения функции fib: 4.599996827892028e-07
#
# Время выполнения функции fib: 4.2500050767557696e-07
#
# Время выполнения функции fib: 3.142500008834759e-05
#
# Время выполнения функции fib: 6.238599962671287e-05
#
# Время выполнения функции fib: 4.579997039400041e-07
#
# Время выполнения функции fib: 4.3599993659881875e-07
#
# Время выполнения функции fib: 3.2281000130751636e-05
#
# Время выполнения функции fib: 4.4600074033951387e-07
#
# Время выполнения функции fib: 4.5399974624160677e-07
#
# Время выполнения функции fib: 4.230005288263783e-07
#
# Время выполнения функции fib: 3.14859998979955e-05
#
# Время выполнения функции fib: 6.21150002189097e-05
#
# Время выполнения функции fib: 0.00012441600028978428
#
# Время выполнения функции fib: 0.00021848400047019823
#
# Время выполнения функции fib: 5.009997039451264e-07
#
# Время выполнения функции fib: 4.229996193316765e-07
#
# Время выполнения функции fib: 3.160699998261407e-05
#
# Время выполнения функции fib: 4.350004019215703e-07
#
# Время выполнения функции fib: 4.4999978854320943e-07
#
# Время выполнения функции fib: 4.3299951357766986e-07
#
# Время выполнения функции fib: 4.244299998390488e-05
#
# Время выполнения функции fib: 8.141000034811441e-05
#
# Время выполнения функции fib: 0.00014449500031332718
#
# Время выполнения функции fib: 4.4199987314641476e-07
#
# Время выполнения функции fib: 4.5899923861725256e-07
#
# Время выполнения функции fib: 4.229996193316765e-07
#
# Время выполнения функции fib: 3.2359999750042334e-05
#
# Время выполнения функции fib: 6.379400019795867e-05
#
# Время выполнения функции fib: 4.55000190413557e-07
#
# Время выполнения функции fib: 4.2099964048247784e-07
#
# Время выполнения функции fib: 3.146600010950351e-05
#
# Время выполнения функции fib: 4.399998942972161e-07
#
# Время выполнения функции fib: 4.429994078236632e-07
#
# Время выполнения функции fib: 4.2500050767557696e-07
#
# Время выполнения функции fib: 3.0885000342095736e-05
#
# Время выполнения функции fib: 6.748499981767964e-05
#
# Время выполнения функции fib: 0.00012936299935972784
#
# Время выполнения функции fib: 0.00022343500040733488
#
# Время выполнения функции fib: 0.00039841499983594986
#
# Время выполнения функции fib: 0.0006456749997596489
#
# Время выполнения функции fib: 4.339999577496201e-07
#
# Время выполнения функции fib: 4.1499970393488184e-07
#
# Время выполнения функции fib: 3.143899994029198e-05
#
# Время выполнения функции fib: 4.339999577496201e-07
#
# Время выполнения функции fib: 4.519997673924081e-07
#
# Время выполнения функции fib: 4.2200008465442806e-07
#
# Время выполнения функции fib: 3.1444000342162326e-05
#
# Время выполнения функции fib: 6.236999979591928e-05
#
# Время выполнения функции fib: 0.0001240920000782353
#
# Время выполнения функции fib: 4.470002750167623e-07
#
# Время выполнения функции fib: 4.5900014811195433e-07
#
# Время выполнения функции fib: 4.200001058052294e-07
#
# Время выполнения функции fib: 3.10970008285949e-05
#
# Время выполнения функции fib: 6.180600030347705e-05
#
# Время выполнения функции fib: 4.4800071918871254e-07
#
# Время выполнения функции fib: 4.5399974624160677e-07
#
# Время выполнения функции fib: 3.126499996142229e-05
#
# Время выполнения функции fib: 4.290004653739743e-07
#
# Время выполнения функции fib: 4.440007614903152e-07
#
# Время выполнения функции fib: 4.270004865247756e-07
#
# Время выполнения функции fib: 3.087999994022539e-05
#
# Время выполнения функции fib: 6.15620001553907e-05
#
# Время выполнения функции fib: 0.0001232029999300721
#
# Время выполнения функции fib: 0.0002152759998352849
#
# Время выполнения функции fib: 0.00036867900053039193
#
# Время выполнения функции fib: 4.3599993659881875e-07
#
# Время выполнения функции fib: 4.4999978854320943e-07
#
# Время выполнения функции fib: 1.3469998521031812e-06
#
# Время выполнения функции fib: 0.04327553799976158
#
# Время выполнения функции fib: 0.04333944399968459
#
# Время выполнения функции fib: 5.689998943125829e-07
#
# Время выполнения функции fib: 5.150004653842188e-07
#
# Время выполнения функции fib: 3.686800027935533e-05
#
# Время выполнения функции fib: 5.29999852005858e-07
#
# Время выполнения функции fib: 7.079997885739431e-07
#
# Время выполнения функции fib: 4.809999154531397e-07
#
# Время выполнения функции fib: 3.4456000321370084e-05
#
# Время выполнения функции fib: 6.804100030421978e-05
#
# Время выполнения функции fib: 0.00013870099974155892
#
# Время выполнения функции fib: 0.04351143800067803
#
# Время выполнения функции fib: 5.229994712863117e-07
#
# Время выполнения функции fib: 4.780004019266926e-07
#
# Время выполнения функции fib: 3.443500008870615e-05
#
# Время выполнения функции fib: 3.6499932321021333e-07
#
# Время выполнения функции fib: 4.229996193316765e-07
#
# Время выполнения функции fib: 3.4599997889017686e-07
#
# Время выполнения функции fib: 3.106900021521142e-05
#
# Время выполнения функции fib: 6.201999985933071e-05
#
# Время выполнения функции fib: 0.0001284299996768823
#
# Время выполнения функции fib: 4.1300063458038494e-07
#
# Время выполнения функции fib: 4.459998308448121e-07
#
# Время выполнения функции fib: 4.200001058052294e-07
#
# Время выполнения функции fib: 3.663100051198853e-05
#
# Время выполнения функции fib: 7.24280007489142e-05
#
# Время выполнения функции fib: 4.67000063508749e-07
#
# Время выполнения функции fib: 4.6300010581035167e-07
#
# Время выполнения функции fib: 3.669400030048564e-05
#
# Время выполнения функции fib: 3.9499991544289514e-07
#
# Время выполнения функции fib: 8.960005288827233e-07
#
# Время выполнения функции fib: 4.67000063508749e-07
#
# Время выполнения функции fib: 3.818200002569938e-05
#
# Время выполнения функции fib: 7.294100032595452e-05
#
# Время выполнения функции fib: 0.0001442399998268229
#
# Время выполнения функции fib: 0.0002507500003048335
#
# Время выполнения функции fib: 0.00041292700007034
#
# Время выполнения функции fib: 0.04397965399948589
#
# Время выполнения функции fib: 0.04437889299970266
#
# Время выполнения функции fib: 0.04505597299976216
#
# Время выполнения функции fib: 0.046189744000002975
#
# Время выполнения функции fib: 0.04803366499982076
#
# Время выполнения функции fib: 8.080005500232801e-07
#
# Время выполнения функции fib: 3.4299955586902797e-07
#
# Время выполнения функции fib: 5.254499956208747e-05
#
# Время выполнения функции fib: 4.049998096888885e-07
#
# Время выполнения функции fib: 7.310000000870787e-07
#
# Время выполнения функции fib: 4.080002327100374e-07
#
# Время выполнения функции fib: 3.2669000574969687e-05
#
# Время выполнения функции fib: 6.552999911946245e-05
#
# Время выполнения функции fib: 0.00015103400073712692
#
# Время выполнения функции fib: 4.459998308448121e-07
#
# Время выполнения функции fib: 4.519997673924081e-07
#
# Время выполнения функции fib: 4.2400006350362673e-07
#
# Время выполнения функции fib: 5.175800015422283e-05
#
# Время выполнения функции fib: 8.50649994390551e-05
#
# Время выполнения функции fib: 4.940002327202819e-07
#
# Время выполнения функции fib: 4.440007614903152e-07
#
# Время выполнения функции fib: 3.3413999517506454e-05
#
# Время выполнения функции fib: 4.599996827892028e-07
#
# Время выполнения функции fib: 7.300004654098302e-07
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 3.3192000046256e-05
#
# Время выполнения функции fib: 6.516299981740303e-05
#
# Время выполнения функции fib: 0.00013037000007898314
#
# Время выполнения функции fib: 0.0002475219998814282
#
# Время выполнения функции fib: 0.0004307079998397967
#
# Время выполнения функции fib: 4.880002961726859e-07
#
# Время выполнения функции fib: 4.5400065573630854e-07
#
# Время выполнения функции fib: 4.3899945012526587e-07
#
# Время выполнения функции fib: 3.4340999263804406e-05
#
# Время выполнения функции fib: 6.7299999500392e-05
#
# Время выполнения функции fib: 4.780004019266926e-07
#
# Время выполнения функции fib: 4.4199987314641476e-07
#
# Время выполнения функции fib: 3.436199949646834e-05
#
# Время выполнения функции fib: 3.670002115541138e-07
#
# Время выполнения функции fib: 4.73000000056345e-07
#
# Время выполнения функции fib: 4.3700038077076897e-07
#
# Время выполнения функции fib: 3.398999979253858e-05
#
# Время выполнения функции fib: 6.684500021947315e-05
#
# Время выполнения функции fib: 0.00013355499959288863
#
# Время выполнения функции fib: 0.00023638099992240313
#
# Время выполнения функции fib: 4.700004865298979e-07
#
# Время выполнения функции fib: 4.429994078236632e-07
#
# Время выполнения функции fib: 3.3192000046256e-05
#
# Время выполнения функции fib: 4.4999978854320943e-07
#
# Время выполнения функции fib: 4.719995558843948e-07
#
# Время выполнения функции fib: 4.4099942897446454e-07
#
# Время выполнения функции fib: 3.295300030004e-05
#
# Время выполнения функции fib: 6.492300053650979e-05
#
# Время выполнения функции fib: 0.00012939400039613247
#
# Время выполнения функции fib: 4.410003384691663e-07
#
# Время выполнения функции fib: 4.880002961726859e-07
#
# Время выполнения функции fib: 4.200001058052294e-07
#
# Время выполнения функции fib: 3.229000049032038e-05
#
# Время выполнения функции fib: 6.386699988070177e-05
#
# Время выполнения функции fib: 4.690000423579477e-07
#
# Время выполнения функции fib: 4.4199987314641476e-07
#
# Время выполнения функции fib: 3.9568999454786535e-05
#
# Время выполнения функции fib: 4.519997673924081e-07
#
# Время выполнения функции fib: 7.620001269970089e-07
#
# Время выполнения функции fib: 4.4200078264111653e-07
#
# Время выполнения функции fib: 3.43570000040927e-05
#
# Время выполнения функции fib: 6.686799952149158e-05
#
# Время выполнения функции fib: 0.00013942700024927035
#
# Время выполнения функции fib: 0.0002348199996049516
#
# Время выполнения функции fib: 0.00039589800053363433
#
# Время выполнения функции fib: 0.0006640599995080265
#
# Время выполнения функции fib: 0.0011261939998803427
#
# Время выполнения функции fib: 4.829998943023384e-07
#
# Время выполнения функции fib: 4.690000423579477e-07
#
# Время выполнения функции fib: 4.5900014811195433e-07
#
# Время выполнения функции fib: 3.2790999284770805e-05
#
# Время выполнения функции fib: 8.223300028475933e-05
#
# Время выполнения функции fib: 4.920002538710833e-07
#
# Время выполнения функции fib: 3.6300025385571644e-07
#
# Время выполнения функции fib: 3.2234000173048116e-05
#
# Время выполнения функции fib: 3.909999577444978e-07
#
# Время выполнения функции fib: 4.7399953473359346e-07
#
# Время выполнения функции fib: 3.909999577444978e-07
#
# Время выполнения функции fib: 4.005699975095922e-05
#
# Время выполнения функции fib: 8.015099956537597e-05
#
# Время выполнения функции fib: 0.00014286200075730449
#
# Время выполнения функции fib: 0.00034434200006216997
#
# Время выполнения функции fib: 3.409995770198293e-07
#
# Время выполнения функции fib: 3.510003807605244e-07
#
# Время выполнения функции fib: 4.0642000385560095e-05
#
# Время выполнения функции fib: 4.43000317318365e-07
#
# Время выполнения функции fib: 6.000000212225132e-07
#
# Время выполнения функции fib: 4.410003384691663e-07
#
# Время выполнения функции fib: 3.4747999961837195e-05
#
# Время выполнения функции fib: 6.726399988110643e-05
#
# Время выполнения функции fib: 0.00014319599995360477
#
# Время выполнения функции fib: 4.1299972508568317e-07
#
# Время выполнения функции fib: 9.310006134910509e-07
#
# ...
#
# Время выполнения функции fib: 0.0009606900002836483
#
# Время выполнения функции fib: 0.0014153210004224093
#
# Время выполнения функции fib: 0.0021425940003609867
#
# Время выполнения функции fib: 0.17799705300058122
#
# Время выполнения функции fib: 4.96999746246729e-07
#
# Время выполнения функции fib: 4.78999936603941e-07
#
# Время выполнения функции fib: 4.200001058052294e-07
#
# Время выполнения функции fib: 3.72220001736423e-05
#
# Время выполнения функции fib: 7.013599952188088e-05
#
# Время выполнения функции fib: 4.5599972509080544e-07
#
# Время выполнения функции fib: 4.860003173234873e-07
#
# Время выполнения функции fib: 3.3942000300157815e-05
#
# Время выполнения функции fib: 4.979992809239775e-07
#
# Время выполнения функции fib: 5.040001269662753e-07
#
# Время выполнения функции fib: 4.5599972509080544e-07
#
# Время выполнения функции fib: 3.3569999686733354e-05
#
# Время выполнения функции fib: 6.822799969086191e-05
#
# Время выполнения функции fib: 0.00013621499965665862
#
# Время выполнения функции fib: 0.00023779599996487377
#
# Время выполнения функции fib: 5.000001692678779e-07
#
# Время выполнения функции fib: 4.5100023271515965e-07
#
# Время выполнения функции fib: 3.286599985585781e-05
#
# Время выполнения функции fib: 4.900002750218846e-07
#
# Время выполнения функции fib: 4.769999577547424e-07
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 3.304599977127509e-05
#
# Время выполнения функции fib: 6.632400072703604e-05
#
# Время выполнения функции fib: 0.00013188000048103277
#
# Время выполнения функции fib: 4.809999154531397e-07
#
# Время выполнения функции fib: 6.079999366193078e-07
#
# Время выполнения функции fib: 4.399998942972161e-07
#
# Время выполнения функции fib: 3.3383999834768474e-05
#
# Время выполнения функции fib: 6.628999926761026e-05
#
# Время выполнения функции fib: 4.929997885483317e-07
#
# Время выполнения функции fib: 4.519997673924081e-07
#
# Время выполнения функции fib: 3.364199983479921e-05
#
# Время выполнения функции fib: 3.9800033846404403e-07
#
# Время выполнения функции fib: 4.90999809699133e-07
#
# Время выполнения функции fib: 5.140000212122686e-07
#
# Время выполнения функции fib: 3.384499996172963e-05
#
# Время выполнения функции fib: 6.846199994470226e-05
#
# Время выполнения функции fib: 0.0001442160000806325
#
# Время выполнения функции fib: 0.00024388600013480755
#
# Время выполнения функции fib: 0.00040699799956200877
#
# Время выполнения функции fib: 0.000675279999995837
#
# Время выполнения функции fib: 5.030005922890268e-07
#
# Время выполнения функции fib: 5.100000635138713e-07
#
# Время выполнения функции fib: 5.2305000281194225e-05
#
# Время выполнения функции fib: 5.279998731566593e-07
#
# Время выполнения функции fib: 4.749999789055437e-07
#
# Время выполнения функции fib: 4.3599993659881875e-07
#
# Время выполнения функции fib: 3.421699966565939e-05
#
# Время выполнения функции fib: 6.86959992890479e-05
#
# Время выполнения функции fib: 0.0001536939998914022
#
# Время выполнения функции fib: 4.1299972508568317e-07
#
# Время выполнения функции fib: 4.860003173234873e-07
#
# Время выполнения функции fib: 5.950005288468674e-07
#
# Время выполнения функции fib: 3.433999972912716e-05
#
# Время выполнения функции fib: 6.774200028303312e-05
#
# Время выполнения функции fib: 6.760001269867644e-07
#
# Время выполнения функции fib: 3.390005076653324e-07
#
# Время выполнения функции fib: 3.207600002497202e-05
#
# Время выполнения функции fib: 3.880004442180507e-07
#
# Время выполнения функции fib: 4.61000126961153e-07
#
# Время выполнения функции fib: 4.319999789004214e-07
#
# Время выполнения функции fib: 3.5693000427272636e-05
#
# Время выполнения функции fib: 7.062399981805356e-05
#
# Время выполнения функции fib: 0.00013544800003728596
#
# Время выполнения функции fib: 0.00023638299990125233
#
# Время выполнения функции fib: 0.00042212899916194146
#
# Время выполнения функции fib: 4.5299930206965655e-07
#
# Время выполнения функции fib: 3.9800033846404403e-07
#
# Время выполнения функции fib: 3.5499942896422e-07
#
# Время выполнения функции fib: 3.304999972897349e-05
#
# Время выполнения функции fib: 6.711200057907263e-05
#
# Время выполнения функции fib: 5.050005711382255e-07
#
# Время выполнения функции fib: 4.530002115643583e-07
#
# Время выполнения функции fib: 3.421099972911179e-05
#
# Время выполнения функции fib: 4.4999978854320943e-07
#
# Время выполнения функции fib: 4.859994078287855e-07
#
# Время выполнения функции fib: 4.019993866677396e-07
#
# Время выполнения функции fib: 3.283500063844258e-05
#
# Время выполнения функции fib: 0.00014401800035557244
#
# Время выполнения функции fib: 0.00021490299968718318
#
# Время выполнения функции fib: 0.000315153999508766
#
# Время выполнения функции fib: 4.2400006350362673e-07
#
# Время выполнения функции fib: 4.489993443712592e-07
#
# Время выполнения функции fib: 3.454000034253113e-05
#
# Время выполнения функции fib: 4.700004865298979e-07
#
# Время выполнения функции fib: 5.290003173286095e-07
#
# Время выполнения функции fib: 4.519997673924081e-07
#
# Время выполнения функции fib: 3.5228999877290335e-05
#
# Время выполнения функции fib: 8.659900049678981e-05
#
# Время выполнения функции fib: 0.00015558799987047678
#
# Время выполнения функции fib: 4.4999978854320943e-07
#
# Время выполнения функции fib: 4.96999746246729e-07
#
# Время выполнения функции fib: 4.1499970393488184e-07
#
# Время выполнения функции fib: 3.495599958114326e-05
#
# Время выполнения функции fib: 8.22060001155478e-05
#
# Время выполнения функции fib: 4.96999746246729e-07
#
# Время выполнения функции fib: 4.249995981808752e-07
#
# Время выполнения функции fib: 3.4299000617465936e-05
#
# Время выполнения функции fib: 3.670002115541138e-07
#
# Время выполнения функции fib: 4.90999809699133e-07
#
# Время выполнения функции fib: 4.700004865298979e-07
#
# Время выполнения функции fib: 3.430699962336803e-05
#
# Время выполнения функции fib: 6.813400068494957e-05
#
# Время выполнения функции fib: 0.0001357869996354566
#
# Время выполнения функции fib: 0.00025118400026258314
#
# Время выполнения функции fib: 0.00044053199962945655
#
# Время выполнения функции fib: 0.0007883099997343379
#
# Время выполнения функции fib: 0.0012426889998096158
#
# Время выполнения функции fib: 0.0019491650000418304
#
# Время выполнения функции fib: 4.5700016926275566e-07
#
# Время выполнения функции fib: 5.080000846646726e-07
#
# Время выполнения функции fib: 3.52100005329703e-05
#
# Время выполнения функции fib: 4.61000126961153e-07
#
# Время выполнения функции fib: 7.019998520263471e-07
#
# Время выполнения функции fib: 7.210001058410853e-07
#
# Время выполнения функции fib: 3.7632999919878785e-05
#
# Время выполнения функции fib: 7.179400017776061e-05
#
# Время выполнения функции fib: 0.00014039300003787503
#
# Время выполнения функции fib: 4.920002538710833e-07
#
# Время выполнения функции fib: 4.7100002120714635e-07
#
# Время выполнения функции fib: 4.3100044422317296e-07
#
# Время выполнения функции fib: 3.452399960224284e-05
#
# Время выполнения функции fib: 7.024000024102861e-05
#
# Время выполнения функции fib: 4.2800002120202407e-07
#
# Время выполнения функции fib: 4.61000126961153e-07
#
# Время выполнения функции fib: 3.731700053322129e-05
#
# Время выполнения функции fib: 4.800003807758912e-07
#
# Время выполнения функции fib: 5.559995770454407e-07
#
# Время выполнения функции fib: 5.450001481221989e-07
#
# Время выполнения функции fib: 4.167200040683383e-05
#
# Время выполнения функции fib: 8.018100015760865e-05
#
# Время выполнения функции fib: 0.00015788099972269265
#
# Время выполнения функции fib: 0.0002655500002219924
#
# Время выполнения функции fib: 0.00044093899941799464
#
# Время выполнения функции fib: 4.980001904186793e-07
#
# Время выполнения функции fib: 6.279997251112945e-07
#
# Время выполнения функции fib: 4.369994712760672e-07
#
# Время выполнения функции fib: 3.671299964480568e-05
#
# Время выполнения функции fib: 7.3037999754888e-05
#
# Время выполнения функции fib: 4.900002750218846e-07
#
# Время выполнения функции fib: 6.975000360398553e-06
#
# Время выполнения функции fib: 4.291599998396123e-05
#
# Время выполнения функции fib: 5.849997251061723e-07
#
# Время выполнения функции fib: 8.440001693088561e-07
#
# Время выполнения функции fib: 4.869998520007357e-07
#
# Время выполнения функции fib: 3.740500051208073e-05
#
# Время выполнения функции fib: 0.00012287299978197552
#
# Время выполнения функции fib: 0.013426240000626422
#
# Время выполнения функции fib: 0.013533302999348962
#
# Время выполнения функции fib: 4.5900014811195433e-07
#
# Время выполнения функции fib: 4.520006768871099e-07
#
# Время выполнения функции fib: 3.238599947508192e-05
#
# Время выполнения функции fib: 4.599996827892028e-07
#
# Время выполнения функции fib: 4.260000423528254e-07
#
# Время выполнения функции fib: 4.6799959818599746e-07
#
# Время выполнения функции fib: 3.276499955973122e-05
#
# Время выполнения функции fib: 6.469199979619589e-05
#
# Время выполнения функции fib: 0.00012793299993063556
#
# Время выполнения функции fib: 4.43000317318365e-07
#
# Время выполнения функции fib: 4.500006980379112e-07
#
# Время выполнения функции fib: 4.260000423528254e-07
#
# Время выполнения функции fib: 3.22559999403893e-05
#
# Время выполнения функции fib: 6.362900057865772e-05
#
# Время выполнения функции fib: 4.43000317318365e-07
#
# Время выполнения функции fib: 4.170005922787823e-07
#
# Время выполнения функции fib: 3.136899977107532e-05
#
# Время выполнения функции fib: 4.309995347284712e-07
#
# Время выполнения функции fib: 5.169995347387157e-07
#
# Время выполнения функции fib: 4.0899976738728583e-07
#
# Время выполнения функции fib: 3.1913000384520274e-05
#
# Время выполнения функции fib: 6.262799979595002e-05
#
# Время выполнения функции fib: 0.00012431400045898044
#
# Время выполнения функции fib: 0.0002186169995184173
#
# Время выполнения функции fib: 0.00037748700015072245
#
# Время выполнения функции fib: 0.013941244999841729
#
# Время выполнения функции fib: 0.0144145699996443
#
# Время выполнения функции fib: 4.309995347284712e-07
#
# Время выполнения функции fib: 4.3900035961996764e-07
#
# Время выполнения функции fib: 4.109997462364845e-07
#
# Время выполнения функции fib: 3.171200023643905e-05
#
# Время выполнения функции fib: 6.264299918257166e-05
#
# Время выполнения функции fib: 4.640005499823019e-07
#
# Время выполнения функции fib: 4.1900057112798095e-07
#
# Время выполнения функции fib: 3.1863000003795605e-05
#
# Время выполнения функции fib: 4.3100044422317296e-07
#
# Время выполнения функции fib: 4.6500008465955034e-07
#
# Время выполнения функции fib: 4.289995558792725e-07
#
# Время выполнения функции fib: 3.257899970776634e-05
#
# Время выполнения функции fib: 7.023400030448101e-05
#
# Время выполнения функции fib: 0.00013325300005817553
#
# Время выполнения функции fib: 0.00022613900000578724
#
# Время выполнения функции fib: 4.3000000005122274e-07
#
# Время выполнения функции fib: 4.1499970393488184e-07
#
# Время выполнения функции fib: 3.2203000046138186e-05
#
# Время выполнения функции fib: 4.4200078264111653e-07
#
# Время выполнения функции fib: 4.6500008465955034e-07
#
# Время выполнения функции fib: 4.2400006350362673e-07
#
# Время выполнения функции fib: 3.312199987703934e-05
#
# Время выполнения функции fib: 7.701300000917399e-05
#
# Время выполнения функции fib: 0.0001409880005667219
#
# Время выполнения функции fib: 4.2200008465442806e-07
#
# Время выполнения функции fib: 4.4099942897446454e-07
#
# Время выполнения функции fib: 4.080002327100374e-07
#
# Время выполнения функции fib: 3.2109999665408395e-05
#
# Время выполнения функции fib: 6.339799983834382e-05
#
# Время выполнения функции fib: 4.270004865247756e-07
#
# Время выполнения функции fib: 4.3100044422317296e-07
#
# Время выполнения функции fib: 3.190700044797268e-05
#
# Время выполнения функции fib: 4.099993020645343e-07
#
# Время выполнения функции fib: 3.939994712709449e-07
#
# Время выполнения функции fib: 7.959997674333863e-07
#
# Время выполнения функции fib: 5.937100013397867e-05
#
# Время выполнения функции fib: 9.051300003193319e-05
#
# Время выполнения функции fib: 0.00015305099987017456
#
# Время выполнения функции fib: 0.00024753100024099695
#
# Время выполнения функции fib: 0.0004195650008114171
#
# Время выполнения функции fib: 0.00067673899957299
#
# Время выполнения функции fib: 4.4099942897446454e-07
#
# Время выполнения функции fib: 4.1300063458038494e-07
#
# Время выполнения функции fib: 3.208500038454076e-05
#
# Время выполнения функции fib: 4.309995347284712e-07
#
# Время выполнения функции fib: 4.200001058052294e-07
#
# Время выполнения функции fib: 4.2500050767557696e-07
#
# Время выполнения функции fib: 3.253299928474007e-05
#
# Время выполнения функции fib: 6.346100053633563e-05
#
# Время выполнения функции fib: 0.00012597500062838662
#
# Время выполнения функции fib: 4.489993443712592e-07
#
# Время выполнения функции fib: 4.350004019215703e-07
#
# Время выполнения функции fib: 4.049998096888885e-07
#
# Время выполнения функции fib: 3.1549999221169855e-05
#
# Время выполнения функции fib: 6.282800040935399e-05
#
# Время выполнения функции fib: 4.260000423528254e-07
#
# Время выполнения функции fib: 4.410003384691663e-07
#
# Время выполнения функции fib: 3.114200080744922e-05
#
# Время выполнения функции fib: 4.080002327100374e-07
#
# Время выполнения функции fib: 4.3000000005122274e-07
#
# Время выполнения функции fib: 4.339999577496201e-07
#
# Время выполнения функции fib: 3.204500080755679e-05
#
# Время выполнения функции fib: 6.300099994405173e-05
#
# Время выполнения функции fib: 0.0001246290003109607
#
# Время выполнения функции fib: 0.00021779500002594432
#
# Время выполнения функции fib: 0.0003754839999601245
#
# Время выполнения функции fib: 4.399998942972161e-07
#
# Время выполнения функции fib: 4.6799959818599746e-07
#
# Время выполнения функции fib: 4.169996827840805e-07
#
# Время выполнения функции fib: 3.1595999644196127e-05
#
# Время выполнения функции fib: 6.893000045238296e-05
#
# Время выполнения функции fib: 5.459996827994473e-07
#
# Время выполнения функции fib: 4.439998519956134e-07
#
# Время выполнения функции fib: 3.132000074401731e-05
#
# Время выполнения функции fib: 4.3499949242686853e-07
#
# Время выполнения функции fib: 4.379999154480174e-07
#
# Время выполнения функции fib: 4.140001692576334e-07
#
# Время выполнения функции fib: 3.255000046920031e-05
#
# Время выполнения функции fib: 6.385100004990818e-05
#
# Время выполнения функции fib: 0.0001263859994651284
#
# Время выполнения функции fib: 0.0002368320001551183
#
# Время выполнения функции fib: 4.4600074033951387e-07
#
# Время выполнения функции fib: 4.889998308499344e-07
#
# Время выполнения функции fib: 0.000119194999570027
#
# Время выполнения функции fib: 4.61000126961153e-07
#
# Время выполнения функции fib: 4.3899945012526587e-07
#
# Время выполнения функции fib: 4.2500050767557696e-07
#
# Время выполнения функции fib: 3.164300051139435e-05
#
# Время выполнения функции fib: 6.30449994787341e-05
#
# Время выполнения функции fib: 0.00021267899956001202
#
# Время выполнения функции fib: 4.290004653739743e-07
#
# Время выполнения функции fib: 4.470002750167623e-07
#
# Время выполнения функции fib: 4.0099985199049115e-07
#
# Время выполнения функции fib: 3.1399999897985253e-05
#
# Время выполнения функции fib: 6.223399941518437e-05
#
# Время выполнения функции fib: 4.2400006350362673e-07
#
# Время выполнения функции fib: 4.200001058052294e-07
#
# Время выполнения функции fib: 3.142099922115449e-05
#
# Время выполнения функции fib: 4.5399974624160677e-07
#
# Время выполнения функции fib: 8.550005077267997e-07
#
# Время выполнения функции fib: 4.2400006350362673e-07
#
# Время выполнения функции fib: 3.165900034218794e-05
#
# Время выполнения функции fib: 6.28950001555495e-05
#
# Время выполнения функции fib: 0.0001246149995495216
#
# Время выполнения функции fib: 0.00021641799958160846
#
# Время выполнения функции fib: 0.0004588430001604138
#
# Время выполнения функции fib: 0.0007256379994942108
#
# Время выполнения функции fib: 0.0011313630002405262
#
# Время выполнения функции fib: 0.0018384699997113785
#
# Время выполнения функции fib: 0.016283404999740014
#
# Время выполнения функции fib: 0.01826249900022958
#
# Время выполнения функции fib: 0.19629166899994743
#
# Время выполнения функции fib: 0.22850163899965992
#
# Время выполнения функции fib: 0.2855429170003845
#
# Время выполнения функции fib: 0.4688887119991705
#
# Время выполнения функции fib: 0.6798652710003807
#
# Время выполнения функции fib: 1.0590307089996713
#
# Время выполнения функции fib: 1.5235282319999897
#
# Время выполнения функции fib: 2.618591438000294
#
# Время выполнения функции fib: 3.9358346249991882
#
# CPU times: user 3.71 s, sys: 285 ms, total: 3.99 s
# Wall time: 3.94 s
# 6765

# %%
@benchmark
@memo
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
# %%time
fib(20)
# Out:
# Время выполнения функции fmemo: 2.3400007194140926e-06
#
# Время выполнения функции fmemo: 1.7510001271148212e-06
#
# Время выполнения функции fmemo: 0.00010332199963158928
#
# Время выполнения функции fmemo: 1.2609998520929366e-06
#
# Время выполнения функции fmemo: 9.900004442897625e-07
#
# Время выполнения функции fmemo: 4.973399973096093e-05
#
# Время выполнения функции fmemo: 0.00018836199978977675
#
# Время выполнения функции fmemo: 7.990001904545352e-07
#
# Время выполнения функции fmemo: 8.050001270021312e-07
#
# Время выполнения функции fmemo: 3.768300030060345e-05
#
# Время выполнения функции fmemo: 0.0002607629994599847
#
# Время выполнения функции fmemo: 8.280003385152668e-07
#
# Время выполнения функции fmemo: 8.309998520417139e-07
#
# Время выполнения функции fmemo: 3.454899979260517e-05
#
# Время выполнения функции fmemo: 0.00032998599999700673
#
# Время выполнения функции fmemo: 7.810003808117472e-07
#
# Время выполнения функции fmemo: 7.740000000922009e-07
#
# Время выполнения функции fmemo: 3.35770000674529e-05
#
# Время выполнения функции fmemo: 0.0003999499995188671
#
# Время выполнения функции fmemo: 8.249999154941179e-07
#
# Время выполнения функции fmemo: 8.130000423989259e-07
#
# Время выполнения функции fmemo: 3.5013000342587475e-05
#
# Время выполнения функции fmemo: 0.0004897200005871127
#
# Время выполнения функции fmemo: 7.580001692986116e-07
#
# Время выполнения функции fmemo: 7.360004019574262e-07
#
# Время выполнения функции fmemo: 3.456800004641991e-05
#
# Время выполнения функции fmemo: 0.0005589329994108994
#
# Время выполнения функции fmemo: 7.999997251317836e-07
#
# Время выполнения функции fmemo: 7.11000211595092e-07
#
# Время выполнения функции fmemo: 3.3399000130884815e-05
#
# Время выполнения функции fmemo: 0.0006289650000326219
#
# Время выполнения функции fmemo: 9.73000169324223e-07
#
# Время выполнения функции fmemo: 7.540002116002142e-07
#
# Время выполнения функции fmemo: 3.5991000004287343e-05
#
# Время выполнения функции fmemo: 0.0007024859996818122
#
# Время выполнения функции fmemo: 8.03999682830181e-07
#
# Время выполнения функции fmemo: 7.306999577849638e-06
#
# Время выполнения функции fmemo: 0.016601473000264377
#
# Время выполнения функции fmemo: 0.017352548999951978
#
# CPU times: user 9.04 ms, sys: 2 µs, total: 9.04 ms
# Wall time: 17.4 ms
# 6765

# %% [markdown]
# Видим многократное ускорение работы функции при кэшировании результатов: 0,01735 с вместо 3,936 с (более, чем в 200 раз).
